# %% [markdown]
# # Mask R-CNN - Inspect Bottle Trained Model
#
# Code and visualizations to test, debug, and evaluate the Mask R-CNN model.

# %%
import os
import sys
import random
import math
import re
import time
import numpy as np
import tensorflow as tf
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Root directory of the project
ROOT_DIR = os.path.abspath("../")

# Import Mask RCNN
sys.path.append(ROOT_DIR)  # To find local version of the library
from mrcnn import utils
from mrcnn import visualize
from mrcnn.visualize import display_images
import mrcnn.model as modellib
from mrcnn.model import log

import bottle

# %matplotlib inline 

# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Path to Ballon trained weights
# You can download this file from the Releases page
# https://github.com/matterport/Mask_RCNN/releases
BOTTLE_WEIGHTS_PATH = os.path.join(MODEL_DIR,"mask_rcnn_bottle_0100.h5")  # TODO: update this path
# Out:
# Using TensorFlow backend.
# /home/jaikumar/FinalMaskRCNN/MaskRCNN/bottle

# %% [markdown]
# ## Configurations

# %%
config = bottle.BottleConfig()
BOTTLE_DIR = os.path.join(ROOT_DIR, "dataset")

# %%
# Override the training configurations with a few
# changes for inferencing.
class InferenceConfig(config.__class__):
    # Run detection on one image at a time
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

config = InferenceConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.9
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  1024
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  800
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [1024 1024    3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           bottle
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (32, 64, 128, 256, 512)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                1000
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           200
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               50
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# ## Notebook Preferences

# %%
# Device to load the neural network on.
# Useful if you're training a model on the same 
# machine, in which case use CPU and leave the
# GPU for training.
DEVICE = "/gpu:0"  # /cpu:0 or /gpu:0

# Inspect the model in training or inference modes
# values: 'inference' or 'training'
# TODO: code for 'training' test mode not ready yet
TEST_MODE = "inference"

# %%
def get_ax(rows=1, cols=1, size=16):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Adjust the size attribute to control how big to render images
    """
    _, ax = plt.subplots(rows, cols, figsize=(size*cols, size*rows))
    return ax

# %% [markdown]
# ## Load Validation Dataset

# %%
# Load validation dataset
dataset = bottle.BottleDataset()
dataset.load_bottle(BOTTLE_DIR, "val")

dataset_tr = bottle.BottleDataset()
dataset_tr.load_bottle(BOTTLE_DIR, "train")

dataset_tr.prepare()

# Must call before using the dataset
dataset.prepare()
print("Images: {}\nClasses: {}".format(len(dataset_tr.image_ids), dataset_tr.class_names))
print("Images: {}\nClasses: {}".format(len(dataset.image_ids), dataset.class_names))
# Out:
# Images: 177
# Classes: ['BG', 'bottle']
# Images: 15
# Classes: ['BG', 'bottle']

# %% [markdown]
# ## Load Model

# %%
# Create model in inference mode
with tf.device(DEVICE):
    model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR,
                              config=config)
# Out:
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:1919: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3976: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:2018: The name tf.image.resize_nearest_neighbor is deprecated. Please use tf.compat.v1.image.resize_nearest_neighbor instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/mask_rcnn-2.1-py3.7.egg/mrcnn/model.py:399: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/mask_rcnn-2.1-py3.7.egg/mrcnn/model.py:423: calling crop_and_resize_v1 (from tensorflow.python.ops.image_ops_impl) with box_ind is deprecated and will be removed in a future version.
# Instructions for updating:
# box_ind is deprecated, use box_indices instead
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/mask_rcnn-2.1-py3.7.egg/mrcnn/model.py:720: The name tf.sets.set_intersection is deprecated. Please use tf.sets.intersection instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/mask_rcnn-2.1-py3.7.egg/mrcnn/model.py:722: The name tf.sparse_tensor_to_dense is deprecated. Please use tf.sparse.to_dense instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/mask_rcnn-2.1-py3.7.egg/mrcnn/model.py:772: to_float (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.cast` instead.

# %%
# Set path to bottle weights file

# Download file from the Releases page and set its path
# https://github.com/matterport/Mask_RCNN/releases
# weights_path = "/path/to/mask_rcnn_bottle.h5"

# Or, load the last model you trained
#weights_path = model.find_last()

# Load weights
#print("Loading weights ", weights_path)
model.load_weights(BOTTLE_WEIGHTS_PATH, by_name=True)
# Out:
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:174: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:181: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:186: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:190: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:199: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /home/jaikumar//envs/imgaugmask/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:206: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.

# %% [markdown]
# ## Run Detection

# %%
### To Download video from YouTube
#import pytube
#from pytube import YouTube
#import os
#def downloadYouTube(videourl, path):
#    yt = YouTube(videourl)
#    yt = yt.streams.filter(progressive=True, file_extension='mp4').order_by('resolution').desc().first()
#    if not os.path.exists(path):
#        os.makedirs(path)
#        yt.download(path)
#downloadYouTube('https://youtu.be/', './videos')###

# %%
#VIDEO PREDICTIION mp4 format
# Out:
# /home/jaikumar/FinalMaskRCNN/Mask_RCNN

# %%
import cv2
import numpy as np
import os

def random_colors(N):
    np.random.seed(1)
    colors = [tuple(255 * np.random.rand(3)) for _ in range(N)]
    return colors


def apply_mask(image, mask, color, alpha=0.5):
    """apply mask to image"""
    for n, c in enumerate(color):
        image[:, :, n] = np.where(
            mask == 1,
            image[:, :, n] * (1 - alpha) + alpha * c,
            image[:, :, n]
        )
    return image


def display_instances(image, boxes, masks, ids, names, scores):
    """
        take the image and results and apply the mask, box, and Label
    """
    n_instances = boxes.shape[0]
    colors = random_colors(n_instances)

    if not n_instances:
        print('NO INSTANCES TO DISPLAY')
    else:
        assert boxes.shape[0] == masks.shape[-1] == ids.shape[0]

    for i, color in enumerate(colors):
        if not np.any(boxes[i]):
            continue

        y1, x1, y2, x2 = boxes[i]
        label = names[ids[i]]
        score = scores[i] if scores is not None else None
        caption = '{} {:.2f}'.format(label, score) if score else label
        mask = masks[:, :, i]

        image = apply_mask(image, mask, color)
        image = cv2.rectangle(image, (x1, y1), (x2, y2), color, 2)
        image = cv2.putText(
            image, caption, (x1, y1), cv2.FONT_HERSHEY_COMPLEX, 0.7, color, 2
        )

    return image

# %%
pwd
# Out:
# '/home/jaikumar/FinalMaskRCNN/MaskRCNN/bottle'

# %%
import cv2
if __name__ == '__main__' :

    #Mask R-CNN
    ROOT_DIR = os.path.abspath("../")
    MODEL_DIR = os.path.join(ROOT_DIR,"logs")
    VIDEO_DIR = os.path.join(ROOT_DIR, "output")
    VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "savedimgs")
    COCO_MODEL_PATH = os.path.join(MODEL_DIR, "mask_rcnn_bottle_0100.h5")
    if not os.path.exists(COCO_MODEL_PATH):
     utils.download_trained_weights(COCO_MODEL_PATH)
     class InferenceConfig(bottle.BottleConfig):
         GPU_COUNT = 1
         batch_size = 3
         IMAGES_PER_GPU = batch_size
         config = InferenceConfig()
         config.display()
        
# Create model object in inference mode.
model = modellib.MaskRCNN(mode="inference", model_dir=MODEL_DIR,
                              config=config)

#model = modellib.MaskRCNN(mode=”inference”, model_dir=MODEL_DIR, config=config)
# Load weights trained on MS-COCO
model.load_weights(COCO_MODEL_PATH, by_name=True)
class_names = ['BG','bottle']    
video = cv2.VideoCapture(os.path.join(ROOT_DIR,"videos/plasticbottle.mov"));

# Find OpenCV version
(major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')

if int(major_ver)  < 3 :
    fps = video.get(cv2.cv.CV_CAP_PROP_FPS)
    print ("Frames per second using video.get(cv2.cv.CV_CAP_PROP_FPS): {0}".format(fps))
else :
    fps = video.get(cv2.CAP_PROP_FPS)
    print ("Frames per second using video.get(cv2.CAP_PROP_FPS) : {0}".format(fps))

try:
    if not os.path.exists(VIDEO_SAVE_DIR): 
        os.makedirs(VIDEO_SAVE_DIR)
except OSError:
    print ('Error: Creating directory of data')
                
frames = []
frame_count = 0

while True:
    ret, frame = video.read()
    if not ret: 
        break
        
    # Save each frame of the video to a list
    frame_count += 1
    frames.append(frame)
    print('frame_count :{0}'.format(frame_count))
    batch_size=1
    BATCH_SIZE = 1
    if len(frames) == BATCH_SIZE:
        results = model.detect(frames, verbose=0)
        print('Predicted')
        for i, item in enumerate(zip(frames, results)):
            frame = item[0]
            r = item[1]
            frame = display_instances(
            frame, r['rois'], r['masks'], r['class_ids'], class_names, r['scores'])
            name = '{0}.jpg'.format(frame_count + i - batch_size)
            name = os.path.join(VIDEO_SAVE_DIR, name)
            cv2.imwrite(name, frame)
            print('writing to file:{0}'.format(name))
            # Clear the frames array to start the next batch
            frames = []

#capture.release()
video.release();
# Out:
# Frames per second using video.get(cv2.CAP_PROP_FPS) : 25.0
# frame_count :1
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/0.jpg
# frame_count :2
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/1.jpg
# frame_count :3
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/2.jpg
# frame_count :4
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/3.jpg
# frame_count :5
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/4.jpg
# frame_count :6
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/5.jpg
# frame_count :7
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/6.jpg
# frame_count :8
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/7.jpg
# frame_count :9
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/8.jpg
# frame_count :10
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/9.jpg
# frame_count :11
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/10.jpg
# frame_count :12
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/11.jpg
# frame_count :13
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/12.jpg
# frame_count :14
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/13.jpg
# frame_count :15
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/14.jpg
# frame_count :16
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/15.jpg
# frame_count :17
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/16.jpg
# frame_count :18
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/17.jpg
# frame_count :19
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/18.jpg
# frame_count :20
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/19.jpg
# frame_count :21
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/20.jpg
# frame_count :22
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/21.jpg
# frame_count :23
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/22.jpg
# frame_count :24
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/23.jpg
# frame_count :25
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/24.jpg
# frame_count :26
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/25.jpg
# frame_count :27
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/26.jpg
# frame_count :28
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/27.jpg
# frame_count :29
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/28.jpg
# frame_count :30
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/29.jpg
# frame_count :31
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/30.jpg
# frame_count :32
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/31.jpg
# frame_count :33
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/32.jpg
# frame_count :34
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/33.jpg
# frame_count :35
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/34.jpg
# frame_count :36
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/35.jpg
# frame_count :37
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/36.jpg
# frame_count :38
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/37.jpg
# frame_count :39
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/38.jpg
# frame_count :40
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/39.jpg
# frame_count :41
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/40.jpg
# frame_count :42
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/41.jpg
# frame_count :43
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/42.jpg
# frame_count :44
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/43.jpg
# frame_count :45
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/44.jpg
# frame_count :46
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/45.jpg
# frame_count :47
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/46.jpg
# frame_count :48
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/47.jpg
# frame_count :49
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/48.jpg
# frame_count :50
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/49.jpg
# frame_count :51
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/50.jpg
# frame_count :52
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/51.jpg
# frame_count :53
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/52.jpg
# frame_count :54
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/53.jpg
# frame_count :55
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/54.jpg
# frame_count :56
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/55.jpg
# frame_count :57
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/56.jpg
# frame_count :58
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/57.jpg
# frame_count :59
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/58.jpg
# frame_count :60
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/59.jpg
# frame_count :61
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/60.jpg
# frame_count :62
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/61.jpg
# frame_count :63
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/62.jpg
# frame_count :64
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/63.jpg
# frame_count :65
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/64.jpg
# frame_count :66
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/65.jpg
# frame_count :67
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/66.jpg
# frame_count :68
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/67.jpg
# frame_count :69
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/68.jpg
# frame_count :70
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/69.jpg
# frame_count :71
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/70.jpg
# frame_count :72
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/71.jpg
# frame_count :73
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/72.jpg
# frame_count :74
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/73.jpg
# frame_count :75
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/74.jpg
# frame_count :76
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/75.jpg
# frame_count :77
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/76.jpg
# frame_count :78
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/77.jpg
# frame_count :79
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/78.jpg
# frame_count :80
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/79.jpg
# frame_count :81
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/80.jpg
# frame_count :82
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/81.jpg
# frame_count :83
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/82.jpg
# frame_count :84
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/83.jpg
# frame_count :85
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/84.jpg
# frame_count :86
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/85.jpg
# frame_count :87
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/86.jpg
# frame_count :88
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/87.jpg
# frame_count :89
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/88.jpg
# frame_count :90
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/89.jpg
# frame_count :91
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/90.jpg
# frame_count :92
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/91.jpg
# frame_count :93
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/92.jpg
# frame_count :94
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/93.jpg
# frame_count :95
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/94.jpg
# frame_count :96
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/95.jpg
# frame_count :97
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/96.jpg
# frame_count :98
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/97.jpg
# frame_count :99
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/98.jpg
# frame_count :100
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/99.jpg
# frame_count :101
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/100.jpg
# frame_count :102
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/101.jpg
# frame_count :103
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/102.jpg
# frame_count :104
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/103.jpg
# frame_count :105
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/104.jpg
# frame_count :106
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/105.jpg
# frame_count :107
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/106.jpg
# frame_count :108
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/107.jpg
# frame_count :109
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/108.jpg
# frame_count :110
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/109.jpg
# frame_count :111
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/110.jpg
# frame_count :112
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/111.jpg
# frame_count :113
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/112.jpg
# frame_count :114
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/113.jpg
# frame_count :115
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/114.jpg
# frame_count :116
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/115.jpg
# frame_count :117
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/116.jpg
# frame_count :118
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/117.jpg
# frame_count :119
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/118.jpg
# frame_count :120
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/119.jpg
# frame_count :121
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/120.jpg
# frame_count :122
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/121.jpg
# frame_count :123
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/122.jpg
# frame_count :124
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/123.jpg
# frame_count :125
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/124.jpg
# frame_count :126
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/125.jpg
# frame_count :127
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/126.jpg
# frame_count :128
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/127.jpg
# frame_count :129
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/128.jpg
# frame_count :130
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/129.jpg
# frame_count :131
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/130.jpg
# frame_count :132
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/131.jpg
# frame_count :133
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/132.jpg
# frame_count :134
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/133.jpg
# frame_count :135
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/134.jpg
# frame_count :136
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/135.jpg
# frame_count :137
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/136.jpg
# frame_count :138
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/137.jpg
# frame_count :139
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/138.jpg
# frame_count :140
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/139.jpg
# frame_count :141
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/140.jpg
# frame_count :142
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/141.jpg
# frame_count :143
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/142.jpg
# frame_count :144
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/143.jpg
# frame_count :145
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/144.jpg
# frame_count :146
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/145.jpg
# frame_count :147
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/146.jpg
# frame_count :148
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/147.jpg
# frame_count :149
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/148.jpg
# frame_count :150
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/149.jpg
# frame_count :151
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/150.jpg
# frame_count :152
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/151.jpg
# frame_count :153
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/152.jpg
# frame_count :154
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/153.jpg
# frame_count :155
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/154.jpg
# frame_count :156
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/155.jpg
# frame_count :157
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/156.jpg
# frame_count :158
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/157.jpg
# frame_count :159
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/158.jpg
# frame_count :160
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/159.jpg
# frame_count :161
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/160.jpg
# frame_count :162
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/161.jpg
# frame_count :163
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/162.jpg
# frame_count :164
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/163.jpg
# frame_count :165
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/164.jpg
# frame_count :166
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/165.jpg
# frame_count :167
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/166.jpg
# frame_count :168
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/167.jpg
# frame_count :169
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/168.jpg
# frame_count :170
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/169.jpg
# frame_count :171
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/170.jpg
# frame_count :172
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/171.jpg
# frame_count :173
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/172.jpg
# frame_count :174
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/173.jpg
# frame_count :175
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/174.jpg
# frame_count :176
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/175.jpg
# frame_count :177
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/176.jpg
# frame_count :178
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/177.jpg
# frame_count :179
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/178.jpg
# frame_count :180
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/179.jpg
# frame_count :181
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/180.jpg
# frame_count :182
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/181.jpg
# frame_count :183
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/182.jpg
# frame_count :184
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/183.jpg
# frame_count :185
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/184.jpg
# frame_count :186
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/185.jpg
# frame_count :187
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/186.jpg
# frame_count :188
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/187.jpg
# frame_count :189
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/188.jpg
# frame_count :190
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/189.jpg
# frame_count :191
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/190.jpg
# frame_count :192
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/191.jpg
# frame_count :193
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/192.jpg
# frame_count :194
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/193.jpg
# frame_count :195
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/194.jpg
# frame_count :196
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/195.jpg
# frame_count :197
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/196.jpg
# frame_count :198
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/197.jpg
# frame_count :199
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/198.jpg
# frame_count :200
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/199.jpg
# frame_count :201
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/200.jpg
# frame_count :202
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/201.jpg
# frame_count :203
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/202.jpg
# frame_count :204
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/203.jpg
# frame_count :205
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/204.jpg
# frame_count :206
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/205.jpg
# frame_count :207
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/206.jpg
# frame_count :208
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/207.jpg
# frame_count :209
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/208.jpg
# frame_count :210
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/209.jpg
# frame_count :211
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/210.jpg
# frame_count :212
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/211.jpg
# frame_count :213
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/212.jpg
# frame_count :214
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/213.jpg
# frame_count :215
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/214.jpg
# frame_count :216
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/215.jpg
# frame_count :217
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/216.jpg
# frame_count :218
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/217.jpg
# frame_count :219
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/218.jpg
# frame_count :220
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/219.jpg
# frame_count :221
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/220.jpg
# frame_count :222
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/221.jpg
# frame_count :223
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/222.jpg
# frame_count :224
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/223.jpg
# frame_count :225
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/224.jpg
# frame_count :226
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/225.jpg
# frame_count :227
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/226.jpg
# frame_count :228
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/227.jpg
# frame_count :229
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/228.jpg
# frame_count :230
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/229.jpg
# frame_count :231
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/230.jpg
# frame_count :232
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/231.jpg
# frame_count :233
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/232.jpg
# frame_count :234
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/233.jpg
# frame_count :235
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/234.jpg
# frame_count :236
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/235.jpg
# frame_count :237
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/236.jpg
# frame_count :238
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/237.jpg
# frame_count :239
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/238.jpg
# frame_count :240
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/239.jpg
# frame_count :241
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/240.jpg
# frame_count :242
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/241.jpg
# frame_count :243
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/242.jpg
# frame_count :244
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/243.jpg
# frame_count :245
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/244.jpg
# frame_count :246
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/245.jpg
# frame_count :247
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/246.jpg
# frame_count :248
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/247.jpg
# frame_count :249
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/248.jpg
# frame_count :250
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/249.jpg
# frame_count :251
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/250.jpg
# frame_count :252
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/251.jpg
# frame_count :253
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/252.jpg
# frame_count :254
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/253.jpg
# frame_count :255
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/254.jpg
# frame_count :256
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/255.jpg
# frame_count :257
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/256.jpg
# frame_count :258
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/257.jpg
# frame_count :259
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/258.jpg
# frame_count :260
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/259.jpg
# frame_count :261
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/260.jpg
# frame_count :262
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/261.jpg
# frame_count :263
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/262.jpg
# frame_count :264
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/263.jpg
# frame_count :265
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/264.jpg
# frame_count :266
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/265.jpg
# frame_count :267
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/266.jpg
# frame_count :268
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/267.jpg
# frame_count :269
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/268.jpg
# frame_count :270
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/269.jpg
# frame_count :271
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/270.jpg
# frame_count :272
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/271.jpg
# frame_count :273
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/272.jpg
# frame_count :274
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/273.jpg
# frame_count :275
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/274.jpg
# frame_count :276
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/275.jpg
# frame_count :277
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/276.jpg
# frame_count :278
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/277.jpg
# frame_count :279
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/278.jpg
# frame_count :280
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/279.jpg
# frame_count :281
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/280.jpg
# frame_count :282
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/281.jpg
# frame_count :283
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/282.jpg
# frame_count :284
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/283.jpg
# frame_count :285
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/284.jpg
# frame_count :286
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/285.jpg
# frame_count :287
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/286.jpg
# frame_count :288
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/287.jpg
# frame_count :289
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/288.jpg
# frame_count :290
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/289.jpg
# frame_count :291
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/290.jpg
# frame_count :292
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/291.jpg
# frame_count :293
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/292.jpg
# frame_count :294
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/293.jpg
# frame_count :295
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/294.jpg
# frame_count :296
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/295.jpg
# frame_count :297
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/296.jpg
# frame_count :298
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/297.jpg
# frame_count :299
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/298.jpg
# frame_count :300
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/299.jpg
# frame_count :301
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/300.jpg
# frame_count :302
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/301.jpg
# frame_count :303
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/302.jpg
# frame_count :304
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/303.jpg
# frame_count :305
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/304.jpg
# frame_count :306
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/305.jpg
# frame_count :307
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/306.jpg
# frame_count :308
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/307.jpg
# frame_count :309
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/308.jpg
# frame_count :310
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/309.jpg
# frame_count :311
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/310.jpg
# frame_count :312
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/311.jpg
# frame_count :313
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/312.jpg
# frame_count :314
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/313.jpg
# frame_count :315
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/314.jpg
# frame_count :316
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/315.jpg
# frame_count :317
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/316.jpg
# frame_count :318
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/317.jpg
# frame_count :319
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/318.jpg
# frame_count :320
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/319.jpg
# frame_count :321
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/320.jpg
# frame_count :322
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/321.jpg
# frame_count :323
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/322.jpg
# frame_count :324
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/323.jpg
# frame_count :325
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/324.jpg
# frame_count :326
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/325.jpg
# frame_count :327
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/326.jpg
# frame_count :328
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/327.jpg
# frame_count :329
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/328.jpg
# frame_count :330
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/329.jpg
# frame_count :331
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/330.jpg
# frame_count :332
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/331.jpg
# frame_count :333
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/332.jpg
# frame_count :334
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/333.jpg
# frame_count :335
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/334.jpg
# frame_count :336
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/335.jpg
# frame_count :337
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/336.jpg
# frame_count :338
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/337.jpg
# frame_count :339
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/338.jpg
# frame_count :340
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/339.jpg
# frame_count :341
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/340.jpg
# frame_count :342
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/341.jpg
# frame_count :343
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/342.jpg
# frame_count :344
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/343.jpg
# frame_count :345
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/344.jpg
# frame_count :346
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/345.jpg
# frame_count :347
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/346.jpg
# frame_count :348
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/347.jpg
# frame_count :349
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/348.jpg
# frame_count :350
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/349.jpg
# frame_count :351
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/350.jpg
# frame_count :352
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/351.jpg
# frame_count :353
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/352.jpg
# frame_count :354
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/353.jpg
# frame_count :355
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/354.jpg
# frame_count :356
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/355.jpg
# frame_count :357
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/356.jpg
# frame_count :358
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/357.jpg
# frame_count :359
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/358.jpg
# frame_count :360
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/359.jpg
# frame_count :361
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/360.jpg
# frame_count :362
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/361.jpg
# frame_count :363
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/362.jpg
# frame_count :364
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/363.jpg
# frame_count :365
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/364.jpg
# frame_count :366
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/365.jpg
# frame_count :367
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/366.jpg
# frame_count :368
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/367.jpg
# frame_count :369
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/368.jpg
# frame_count :370
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/369.jpg
# frame_count :371
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/370.jpg
# frame_count :372
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/371.jpg
# frame_count :373
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/372.jpg
# frame_count :374
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/373.jpg
# frame_count :375
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/374.jpg
# frame_count :376
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/375.jpg
# frame_count :377
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/376.jpg
# frame_count :378
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/377.jpg
# frame_count :379
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/378.jpg
# frame_count :380
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/379.jpg
# frame_count :381
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/380.jpg
# frame_count :382
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/381.jpg
# frame_count :383
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/382.jpg
# frame_count :384
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/383.jpg
# frame_count :385
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/384.jpg
# frame_count :386
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/385.jpg
# frame_count :387
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/386.jpg
# frame_count :388
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/387.jpg
# frame_count :389
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/388.jpg
# frame_count :390
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/389.jpg
# frame_count :391
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/390.jpg
# frame_count :392
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/391.jpg
# frame_count :393
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/392.jpg
# frame_count :394
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/393.jpg
# frame_count :395
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/394.jpg
# frame_count :396
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/395.jpg
# frame_count :397
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/396.jpg
# frame_count :398
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/397.jpg
# frame_count :399
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/398.jpg
# frame_count :400
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/399.jpg
# frame_count :401
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/400.jpg
# frame_count :402
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/401.jpg
# frame_count :403
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/402.jpg
# frame_count :404
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/403.jpg
# frame_count :405
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/404.jpg
# frame_count :406
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/405.jpg
# frame_count :407
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/406.jpg
# frame_count :408
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/407.jpg
# frame_count :409
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/408.jpg
# frame_count :410
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/409.jpg
# frame_count :411
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/410.jpg
# frame_count :412
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/411.jpg
# frame_count :413
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/412.jpg
# frame_count :414
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/413.jpg
# frame_count :415
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/414.jpg
# frame_count :416
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/415.jpg
# frame_count :417
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/416.jpg
# frame_count :418
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/417.jpg
# frame_count :419
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/418.jpg
# frame_count :420
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/419.jpg
# frame_count :421
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/420.jpg
# frame_count :422
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/421.jpg
# frame_count :423
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/422.jpg
# frame_count :424
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/423.jpg
# frame_count :425
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/424.jpg
# frame_count :426
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/425.jpg
# frame_count :427
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/426.jpg
# frame_count :428
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/427.jpg
# frame_count :429
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/428.jpg
# frame_count :430
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/429.jpg
# frame_count :431
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/430.jpg
# frame_count :432
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/431.jpg
# frame_count :433
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/432.jpg
# frame_count :434
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/433.jpg
# frame_count :435
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/434.jpg
# frame_count :436
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/435.jpg
# frame_count :437
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/436.jpg
# frame_count :438
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/437.jpg
# frame_count :439
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/438.jpg
# frame_count :440
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/439.jpg
# frame_count :441
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/440.jpg
# frame_count :442
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/441.jpg
# frame_count :443
# Predicted
# writing to file:/home/jaikumar/FinalMaskRCNN/MaskRCNN/videos/savedimgs/442.jpg

# %%
def make_video(outvid, images=None, fps=30, size=None,
               is_color=True, format="FMP4"):
    from cv2 import VideoWriter, VideoWriter_fourcc, imread, resize
    fourcc = VideoWriter_fourcc(*format)
    vid = None
    for image in images:
        if not os.path.exists(image):
            raise FileNotFoundError(image)
        img = imread(image)
        if vid is None:
            if size is None:
                size = img.shape[1], img.shape[0]
            vid = VideoWriter(outvid, fourcc, float(fps), size, is_color)
        if size[0] != img.shape[1] and size[1] != img.shape[0]:
            img = resize(img, size)
        vid.write(img)
    vid.release()
    return vid

import glob
import os
# Directory of images to run detection on
#ROOT_DIR = os.getcwd()
OUT_DIR = os.path.join(ROOT_DIR, "output")
VIDEO_SAVE_DIR = os.path.join(VIDEO_DIR, "savedimgs")
images = list(glob.iglob(os.path.join(VIDEO_SAVE_DIR, '*.*')))
# Sort the images by integer index
images = sorted(images, key=lambda x: float(os.path.split(x)[1][:-3]))

outvid = os.path.join(OUT_DIR, "videosegment.mp4")
make_video(outvid, images, fps=30)
# Out:
# <VideoWriter 0x7fc7e3d7ab90>

# %%
# !ls -alh ../output/
# Out:
# total 36M
# drwxr-xr-x  3 jaikumar fyp    6 Oct  7  2020 .
# drwxr-xr-x 17 jaikumar fyp   24 Oct  7 12:24 ..
# drwxr-xr-x  2 jaikumar fyp    2 Sep 28 01:35 .ipynb_checkpoints
# -rw-r--r--  1 jaikumar fyp 901K Sep 28 01:19 outimage_20200928T011057.png
# -rw-r--r--  1 jaikumar fyp  35M Oct  3 10:48 outvideo_20201003T103707.avi
# -rw-r--r--  1 jaikumar fyp  23M Oct  7  2020 videosegment.mp4
